# %% [markdown]
# <a href="https://colab.research.google.com/github/clapinel/CPD_Crime_Senior_Thesis/blob/master/2_4_Marijuana_Incidents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# imports 
import pandas as pd

# %%
file_name = '/content/drive/My Drive/Crimes_-_2001_to_present.csv'

# %%
all_results = pd.read_csv(file_name)
# filter to keep certain years 
all_results = all_results.query('Year>2007')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
all_results.dropna()
# Out:
#                ID Case Number  ...  Longitude                       Location
# 60296    11556037    JC103643  ... -87.906094   (42.002816387, -87.90609433)
# 62216    11626027    JC188126  ... -87.633860   (41.88336939, -87.633860272)
# 62557    11622422    JC183696  ... -87.606781  (41.825346902, -87.606780575)
# 62590    11625922    JC185669  ... -87.672499  (42.016541612, -87.672499325)
# 62591    11622907    JC185406  ... -87.606961    (41.825298645, -87.6069609)
# ...           ...         ...  ...        ...                            ...
# 7108792   9999998    HY188874  ... -87.718022  (41.939207846, -87.718021657)
# 7108793   9999999    HY189683  ... -87.767226  (41.959943835, -87.767225719)
# 7108795  11700926    JC279725  ... -87.717040  (41.862830429, -87.717040084)
# 7108796     24560    JC279072  ... -87.659660  (41.864278228, -87.659660218)
# 7108797     24559    JC278908  ... -87.659682  (41.864278357, -87.659682244)
#
# [3810430 rows x 22 columns]

# %%
plot_by_hour = all_results['Description'].value_counts().keys().tolist()
plot_by_hour
cannabis = ["MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA","CALCULATED CANNABIS CONSPIRACY","DELIVER CANNABIS TO PERSON <18","POSSESS - CANNABIS 30 GRAMS OR LESS","VIOLATION OF SMOKING BAN","MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM","POSSESS - CANNABIS MORE THAN 30 GRAMS","POSSESSION: SYNTHETIC MARIJUANA","ATTEMPT POSSESSION CANNABIS","CANNABIS PLANT","MANU/DEL:CANNABIS 10GM OR LESS","MANU/DEL:CANNABIS OVER 10 GMS","POSS: CANNABIS 30GMS OR LESS", "POSS: CANNABIS MORE THAN 30GM"]
gun = ["ATTEMPT ARMED: HANDGUN","AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM","ATTEMPT AGG: OTHER FIREARM","DEFACE IDENTIFICATION MARKS OF FIREARM","ATTEMPT ARMED - OTHER FIREARM","UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL","ARMED VIOLENCE","AGGRAVATED PROTECTED EMPLOYEE - HANDGUN","AGGRAVATED DOMESTIC BATTERY - HANDGUN","UNLAWFUL POSSESSION - AMMUNITION","ARMED - OTHER FIREARM","UNLAWFUL POSSESSION - OTHER FIREARM","POSSESS FIREARM / AMMUNITION - NO FOID CARD","AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM,""UNLAWFUL USE - OTHER FIREARM","AGGRAVATED PO: OTHER FIREARM","AGG PRO.EMP: OTHER FIREARM","UNLAWFUL SALE OTHER FIREARM","UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL","ATTEMPT ARMED - HANDGUN","ATTEMPT AGG: HANDGUN","FIREARM REGISTRATION VIOLATION","UNLAWFUL USE - HANDGUN","ATTEMPT: ARMED-OTHER FIREARM","ARMED WHILE UNDER THE INFLUENCE","AGGRAVATED DOMESTIC BATTERY: HANDGUN","AGG PRO.EMP: HANDGUN","UNLAWFUL POSSESSION - HANDGUN","ARMED - HANDGUN","UNLAWFUL USE OTHER FIREARM","AGGRAVATED PO: HANDGUN","ARMED: OTHER FIREARM","UNLAWFUL POSS AMMUNITION","POSS FIREARM/AMMO:NO FOID CARD","AGGRAVATED - HANDGUN","AGGRAVATED: OTHER FIREARM","RECKLESS FIREARM DISCHARGE","UNLAWFUL POSS OTHER FIREARM","UNLAWFUL USE HANDGUN","ARMED: HANDGUN","UNLAWFUL POSS OF HANDGUN", "AGGRAVATED: HANDGUN"]
look_into = ["GUN OFFENDER - ANNUAL REGISTRATION","UNLAWFUL SALE HANDGUN","GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION","GUN OFFENDER: DUTY TO REGISTER","GUN OFFENDER: ANNUAL REGISTRATION","ILLEGAL POSSESSION BY MINOR","ATTEMPT POSSESSION NARCOTICS"]
# instead of doing yes no in columns
# write name of crime
# else False

# need to clean the lisys 
# replace all - and : 
# remove spaces, chip words

# %%
print(len(cannabis))
cannabis
# Out:
# 14
# ['MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#  'CALCULATED CANNABIS CONSPIRACY',
#  'DELIVER CANNABIS TO PERSON <18',
#  'POSSESS - CANNABIS 30 GRAMS OR LESS',
#  'VIOLATION OF SMOKING BAN',
#  'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM',
#  'POSSESS - CANNABIS MORE THAN 30 GRAMS',
#  'POSSESSION: SYNTHETIC MARIJUANA',
#  'ATTEMPT POSSESSION CANNABIS',
#  'CANNABIS PLANT',
#  'MANU/DEL:CANNABIS 10GM OR LESS',
#  'MANU/DEL:CANNABIS OVER 10 GMS',
#  'POSS: CANNABIS 30GMS OR LESS',
#  'POSS: CANNABIS MORE THAN 30GM']

# %%
# clean cannabis crimes 
all_results = all_results.replace('POSSESS - CANNABIS MORE THAN 30 GRAMS','POSS: CANNABIS MORE THAN 30GM')
cannabis.remove('POSSESS - CANNABIS MORE THAN 30 GRAMS')
print(len(cannabis))
cannabis
# Out:
# 13 ['MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA', 'CALCULATED CANNABIS CONSPIRACY', 'DELIVER CANNABIS TO PERSON <18', 'POSSESS - CANNABIS 30 GRAMS OR LESS', 'VIOLATION OF SMOKING BAN', 'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM', 'POSSESSION: SYNTHETIC MARIJUANA', 'ATTEMPT POSSESSION CANNABIS', 'CANNABIS PLANT', 'MANU/DEL:CANNABIS 10GM OR LESS', 'MANU/DEL:CANNABIS OVER 10 GMS', 'POSS: CANNABIS 30GMS OR LESS', 'POSS: CANNABIS MORE THAN 30GM']

# %%
all_results = all_results.replace('POSSESS - CANNABIS 30 GRAMS OR LESS','POSS: CANNABIS 30GMS OR LESS')
cannabis.remove('POSSESS - CANNABIS 30 GRAMS OR LESS')
cannabis
# Out:
# ['MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#  'CALCULATED CANNABIS CONSPIRACY',
#  'DELIVER CANNABIS TO PERSON <18',
#  'VIOLATION OF SMOKING BAN',
#  'MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM',
#  'POSSESSION: SYNTHETIC MARIJUANA',
#  'ATTEMPT POSSESSION CANNABIS',
#  'CANNABIS PLANT',
#  'MANU/DEL:CANNABIS 10GM OR LESS',
#  'MANU/DEL:CANNABIS OVER 10 GMS',
#  'POSS: CANNABIS 30GMS OR LESS',
#  'POSS: CANNABIS MORE THAN 30GM']

# %%
all_results = all_results.replace('POSSESSION: SYNTHETIC MARIJUANA','POSS: SYNTHETIC MARIJUANA')
all_results = all_results.replace('MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM','MANU/DEL:CANNABIS OVER 10 GMS')
cannabis.remove('POSSESSION: SYNTHETIC MARIJUANA')
cannabis.remove('MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM')
print(len(cannabis))
cannabis
# Out:
# 10
# ['MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#  'CALCULATED CANNABIS CONSPIRACY',
#  'DELIVER CANNABIS TO PERSON <18',
#  'VIOLATION OF SMOKING BAN',
#  'ATTEMPT POSSESSION CANNABIS',
#  'CANNABIS PLANT',
#  'MANU/DEL:CANNABIS 10GM OR LESS',
#  'MANU/DEL:CANNABIS OVER 10 GMS',
#  'POSS: CANNABIS 30GMS OR LESS',
#  'POSS: CANNABIS MORE THAN 30GM']

# %%
cannabis.append('POSS: SYNTHETIC MARIJUANA')

# %%
print(len(cannabis))
cannabis
# Out:
# 11
# ['MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA',
#  'CALCULATED CANNABIS CONSPIRACY',
#  'DELIVER CANNABIS TO PERSON <18',
#  'VIOLATION OF SMOKING BAN',
#  'ATTEMPT POSSESSION CANNABIS',
#  'CANNABIS PLANT',
#  'MANU/DEL:CANNABIS 10GM OR LESS',
#  'MANU/DEL:CANNABIS OVER 10 GMS',
#  'POSS: CANNABIS 30GMS OR LESS',
#  'POSS: CANNABIS MORE THAN 30GM',
#  'POSS: SYNTHETIC MARIJUANA']

# %%
# ok now clean the gun list

# %%
print(len(gun))
gun.sort()
gun
# Out:
# 41
# ['AGG PRO.EMP: HANDGUN',
#  'AGG PRO.EMP: OTHER FIREARM',
#  'AGGRAVATED - HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY - HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM,UNLAWFUL USE - OTHER FIREARM',
#  'AGGRAVATED PO: HANDGUN',
#  'AGGRAVATED PO: OTHER FIREARM',
#  'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN',
#  'AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM',
#  'AGGRAVATED: HANDGUN',
#  'AGGRAVATED: OTHER FIREARM',
#  'ARMED - HANDGUN',
#  'ARMED - OTHER FIREARM',
#  'ARMED VIOLENCE',
#  'ARMED WHILE UNDER THE INFLUENCE',
#  'ARMED: HANDGUN',
#  'ARMED: OTHER FIREARM',
#  'ATTEMPT AGG: HANDGUN',
#  'ATTEMPT AGG: OTHER FIREARM',
#  'ATTEMPT ARMED - HANDGUN',
#  'ATTEMPT ARMED - OTHER FIREARM',
#  'ATTEMPT ARMED: HANDGUN',
#  'ATTEMPT: ARMED-OTHER FIREARM',
#  'DEFACE IDENTIFICATION MARKS OF FIREARM',
#  'FIREARM REGISTRATION VIOLATION',
#  'POSS FIREARM/AMMO:NO FOID CARD',
#  'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
# ...

# %%
# make list hanggun and firearn
# or simplify alot in other lism

# %%
# clean guns 
all_results = all_results.replace('ATTEMPT ARMED - HANDGUN','POSS: SYNTHETIC MARIJUANA')
all_results = all_results.replace('UNLAWFUL USE - HANDGUN','UNLAWFUL USE HANDGUN')
gun.remove('ATTEMPT ARMED - HANDGUN')
gun.remove('UNLAWFUL USE - HANDGUN')
all_results = all_results.replace('UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL','UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL')
gun.remove('UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL')
all_results = all_results.replace('UNLAWFUL POSSESSION - OTHER FIREARM', 'UNLAWFUL POSS OTHER FIREARM')
gun.remove('UNLAWFUL POSSESSION - OTHER FIREARM')

all_results = all_results.replace('UNLAWFUL POSSESSION - HANDGUN', 'UNLAWFUL POSS OF HANDGUN')
gun.remove('UNLAWFUL POSSESSION - HANDGUN')
all_results = all_results.replace('UNLAWFUL POSSESSION - AMMUNITION', 'UNLAWFUL POSS AMMUNITION')
gun.remove('UNLAWFUL POSSESSION - AMMUNITION')

print(len(gun))
gun
# Out:
# 35
# ['AGG PRO.EMP: HANDGUN',
#  'AGG PRO.EMP: OTHER FIREARM',
#  'AGGRAVATED - HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY - HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM,UNLAWFUL USE - OTHER FIREARM',
#  'AGGRAVATED PO: HANDGUN',
#  'AGGRAVATED PO: OTHER FIREARM',
#  'AGGRAVATED PROTECTED EMPLOYEE - HANDGUN',
#  'AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM',
#  'AGGRAVATED: HANDGUN',
#  'AGGRAVATED: OTHER FIREARM',
#  'ARMED - HANDGUN',
#  'ARMED - OTHER FIREARM',
#  'ARMED VIOLENCE',
#  'ARMED WHILE UNDER THE INFLUENCE',
#  'ARMED: HANDGUN',
#  'ARMED: OTHER FIREARM',
#  'ATTEMPT AGG: HANDGUN',
#  'ATTEMPT AGG: OTHER FIREARM',
#  'ATTEMPT ARMED - OTHER FIREARM',
#  'ATTEMPT ARMED: HANDGUN',
#  'ATTEMPT: ARMED-OTHER FIREARM',
#  'DEFACE IDENTIFICATION MARKS OF FIREARM',
#  'FIREARM REGISTRATION VIOLATION',
#  'POSS FIREARM/AMMO:NO FOID CARD',
#  'POSSESS FIREARM / AMMUNITION - NO FOID CARD',
#  'RECKLESS FIREARM DISCHARGE',
# ...

# %%
all_results = all_results.replace('AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM','AGG PRO.EMP: OTHER FIREARM')
gun.remove('AGGRAVATED PROTECTED EMPLOYEE - OTHER FIREARM')

all_results = all_results.replace('AGGRAVATED PROTECTED EMPLOYEE - HANDGUN','AGG PRO.EMP: HANDGUN')
gun.remove('AGGRAVATED PROTECTED EMPLOYEE - HANDGUN')

all_results = all_results.replace('AGGRAVATED - HANDGUN', 'AGGRAVATED: HANDGUN')
gun.remove('AGGRAVATED - HANDGUN')

all_results = all_results.replace('AGGRAVATED DOMESTIC BATTERY - HANDGUN', 'AGGRAVATED DOMESTIC BATTERY: HANDGUN')
gun.remove('AGGRAVATED DOMESTIC BATTERY - HANDGUN')

all_results = all_results.replace('ARMED - HANDGUN', 'ARMED: HANDGUN')
gun.remove('ARMED - HANDGUN')

all_results = all_results.replace('ATTEMPT: ARMED - OTHER FIREARM', 'ATTEMPT: ARMED-OTHER FIREARM')
gun.remove('ATTEMPT ARMED - OTHER FIREARM')

all_results = all_results.replace('POSSESS FIREARM / AMMUNITION - NO FOID CARD', 'POSS FIREARM/AMMO:NO FOID CARD')
gun.remove('POSSESS FIREARM / AMMUNITION - NO FOID CARD')

# %%
print(len(gun))
gun
# Out:
# 28
# ['AGG PRO.EMP: HANDGUN',
#  'AGG PRO.EMP: OTHER FIREARM',
#  'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM,UNLAWFUL USE - OTHER FIREARM',
#  'AGGRAVATED PO: HANDGUN',
#  'AGGRAVATED PO: OTHER FIREARM',
#  'AGGRAVATED: HANDGUN',
#  'AGGRAVATED: OTHER FIREARM',
#  'ARMED - OTHER FIREARM',
#  'ARMED VIOLENCE',
#  'ARMED WHILE UNDER THE INFLUENCE',
#  'ARMED: HANDGUN',
#  'ARMED: OTHER FIREARM',
#  'ATTEMPT AGG: HANDGUN',
#  'ATTEMPT AGG: OTHER FIREARM',
#  'ATTEMPT ARMED: HANDGUN',
#  'ATTEMPT: ARMED-OTHER FIREARM',
#  'DEFACE IDENTIFICATION MARKS OF FIREARM',
#  'FIREARM REGISTRATION VIOLATION',
#  'POSS FIREARM/AMMO:NO FOID CARD',
#  'RECKLESS FIREARM DISCHARGE',
#  'UNLAWFUL POSS AMMUNITION',
#  'UNLAWFUL POSS OF HANDGUN',
#  'UNLAWFUL POSS OTHER FIREARM',
#  'UNLAWFUL SALE OTHER FIREARM',
#  'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL',
#  'UNLAWFUL USE HANDGUN',
#  'UNLAWFUL USE OTHER FIREARM']

# %%
all_results = all_results.replace('ARMED - OTHER FIREARM','ARMED: OTHER FIREARM')
gun.remove('ARMED - OTHER FIREARM')

# %%
gun
# Out:
# ['AGG PRO.EMP: HANDGUN',
#  'AGG PRO.EMP: OTHER FIREARM',
#  'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#  'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM,UNLAWFUL USE - OTHER FIREARM',
#  'AGGRAVATED PO: HANDGUN',
#  'AGGRAVATED PO: OTHER FIREARM',
#  'AGGRAVATED: HANDGUN',
#  'AGGRAVATED: OTHER FIREARM',
#  'ARMED VIOLENCE',
#  'ARMED WHILE UNDER THE INFLUENCE',
#  'ARMED: HANDGUN',
#  'ARMED: OTHER FIREARM',
#  'ATTEMPT AGG: HANDGUN',
#  'ATTEMPT AGG: OTHER FIREARM',
#  'ATTEMPT ARMED: HANDGUN',
#  'ATTEMPT: ARMED-OTHER FIREARM',
#  'DEFACE IDENTIFICATION MARKS OF FIREARM',
#  'FIREARM REGISTRATION VIOLATION',
#  'POSS FIREARM/AMMO:NO FOID CARD',
#  'RECKLESS FIREARM DISCHARGE',
#  'UNLAWFUL POSS AMMUNITION',
#  'UNLAWFUL POSS OF HANDGUN',
#  'UNLAWFUL POSS OTHER FIREARM',
#  'UNLAWFUL SALE OTHER FIREARM',
#  'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL',
#  'UNLAWFUL USE HANDGUN',
#  'UNLAWFUL USE OTHER FIREARM']

# %%
# make dataframe with only crimes in gun list
cannabis_filter = all_results['Description'].isin(['MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA','CALCULATED CANNABIS CONSPIRACY','DELIVER CANNABIS TO PERSON <18','POSSESS - CANNABIS 30 GRAMS OR LESS','VIOLATION OF SMOKING BAN','MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAM','POSSESS - CANNABIS MORE THAN 30 GRAMS','POSSESSION: SYNTHETIC MARIJUANA','ATTEMPT POSSESSION CANNABIS','CANNABIS PLANT','MANU/DEL:CANNABIS 10GM OR LESS','MANU/DEL:CANNABIS OVER 10 GMS','POSS: CANNABIS 30GMS OR LESS','POSS: CANNABIS MORE THAN 30GM'])
cannabis_filter.value_counts()
# all false
# Out:
# False    3687578
# True      164452
# Name: Description, dtype: int64

# %%
cannabis_df = all_results[cannabis_filter]
cannabis_df
# Out:
#                ID Case Number  ...  Longitude                       Location
# 84        9771966    HX347197  ...        NaN                            NaN
# 164       9745335    HX369977  ...        NaN                            NaN
# 419       9648188    HX215795  ...        NaN                            NaN
# 447      10898827    HW262738  ...        NaN                            NaN
# 591      10293585    HY476300  ...        NaN                            NaN
# ...           ...         ...  ...        ...                            ...
# 7108750   9999946    HY189905  ... -87.695309   (41.847149067, -87.69530883)
# 7108754   9999950    HY189920  ... -87.610410  (41.685451645, -87.610410484)
# 7108758   9999954    HY189914  ... -87.737314   (41.89701552, -87.737313736)
# 7108770   9999969    HY189942  ... -87.738538  (41.881892843, -87.738537596)
# 7108778   9999977    HY189948  ... -87.723462   (41.88897351, -87.723461985)
#
# [164452 rows x 22 columns]

# %%
all_results[gun_df]
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []

# %%
plot_by_hour = all_results['Description'].value_counts().keys().tolist()

plot_for_loc = all_results['Description'].value_counts()
plot_for_loc
#plot_by_hour
# Out:
# SIMPLE                                            400822
# DOMESTIC BATTERY SIMPLE                           337924
# $500 AND UNDER                                    316316
# OVER $500                                         206045
# TO VEHICLE                                        204904
#                                                    ...
# ATTEMPT ARMED: HANDGUN                                 1
# REGISTER FED GAMBLING STAMP                            1
# ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON            1
# AGGRAVATED: HANDS / FIST / FEET SERIOUS INJURY         1
# SOLICITING FOR BUSINESS                                1
# Name: Description, Length: 492, dtype: int64

# %%
#plot_by_hour
